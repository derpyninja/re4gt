# %%
import os
import copy
import numpy as np
import pandas as pd
import geopandas as gpd

from pathlib import Path

from src import utils, stats_utils
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context("paper", font_scale=1.25)

from src.data.lfs import EulfsDs

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config_paths = "paths_config.yml"
config_data = "data_config.yml"

# %%
eulfs = EulfsDs(fn_config_path=config_paths, fn_config_data=config_data)
# Out:
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\numpy\lib\nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(

# %%
fpath_fr = r"C:\eurostat_data\raw\Yearly_Data\YearlyFiles_83_2019\_YearlyFiles\FR_YEAR_1998_onwards\FR2019_y.csv"
fpath_de = r"C:\eurostat_data\raw\Yearly_Data\YearlyFiles_83_2019\_YearlyFiles\DE_YEAR_1998_onwards\DE2019_y.csv"
fpath_pl = r"C:\eurostat_data\raw\Yearly_Data\YearlyFiles_83_2019\_YearlyFiles\PL_YEAR_1998_onwards\PL2019_y.csv"
fpath_bg = r"C:\eurostat_data\raw\Yearly_Data\YearlyFiles_83_2019\_YearlyFiles\BG_YEAR_1998_onwards\BG2019_y.csv"

# %%
cntry = "MT"
fpath = r"C:\eurostat_data\raw\Yearly_Data\YearlyFiles_83_2019\_YearlyFiles" \
        r"\{}_YEAR_1998_onwards\{}2019_y.csv".format(cntry, cntry)

df = pd.read_csv(fpath, usecols=eulfs.variables, na_values=eulfs.na_values,
                 dtype=eulfs.dtypes_in)
df[df.COUNTRYW == '000-OWN COUNTRY']
df
# Out:
#       SEX WSTATOR NACE1D ISCO3D         COUNTRYW REGIONW FTPT REFYEAR COUNTRY  \
# 0       1       5    NaN    NaN   NOT APPLICABLE     NaN  NaN    2019      MT
# 1       2       5    NaN    NaN   NOT APPLICABLE     NaN  NaN    2019      MT
# 2       2       5    NaN    NaN   NOT APPLICABLE     NaN  NaN    2019      MT
# 3       1       1      H    800  000-OWN COUNTRY     NaN    1    2019      MT
# 4       1       5    NaN    NaN   NOT APPLICABLE     NaN  NaN    2019      MT
# ...    ..     ...    ...    ...              ...     ...  ...     ...     ...
# 20971   1       1      K    100  000-OWN COUNTRY     NaN    1    2019      MT
# 20972   2       1      K    300  000-OWN COUNTRY     NaN    1    2019      MT
# 20973   1       1      C    200  000-OWN COUNTRY     NaN    1    2019      MT
# 20974   2       5    NaN    NaN   NOT APPLICABLE     NaN  NaN    2019      MT
# 20975   1       5    NaN    NaN   NOT APPLICABLE     NaN  NaN    2019      MT
#
#       REGION DEGURBA HHTYPE    COEFF AGE ILOSTAT EDUC4WN HATLEV1D MAINSTAT  \
# 0        NaN       1      1  0.01375  77       3       0        M        4
# 1        NaN       1      1  0.01100  77       3       0        M        4
# 2        NaN       1      1  0.01600  47       3       0        L        7
# 3        NaN       1      1  0.01225  52       1       0        L        1
# 4        NaN       1      1  0.01725  22       2       1        L        8
# ...      ...     ...    ...      ...  ..     ...     ...      ...      ...
# 20971    NaN       2      1  0.02250  57       1       0        M        1
# 20972    NaN       2      1  0.01875  52       1       0        M        1
# 20973    NaN       2      1  0.03250  27       1       0        H        1
# 20974    NaN       2      1  0.04875  37       2       1        L        2
# 20975    NaN       2      1  0.02575  17       3       1        M        3
#
#       INCDECIL
# 0          NaN
# 1          NaN
# 2          NaN
# 3           08
# 4          NaN
# ...        ...
# 20971       10
# 20972       08
# 20973       08
# 20974      NaN
# 20975      NaN
#
# [20976 rows x 19 columns]

# %%
df_all = eulfs.read(year=2019, covariates=True)

# %%
df_all
# Out:
#         SEX WSTATOR NACE1D ISCO3D COUNTRYW REGIONW FTPT REFYEAR COUNTRY  \
# 0         1       1      C    132       AT      12    1    2019      AT
# 1         1       1      G    311       AT      12    1    2019      AT
# 2         2       1      G    411       AT      12    1    2019      AT
# 3         2       1      Q    911       AT      12    1    2019      AT
# 4         1       1      O    011       AT      12    1    2019      AT
# ...      ..     ...    ...    ...      ...     ...  ...     ...     ...
# 1546564   1       2      G    421       UK      M0    2    2019      UK
# 1546565   1       1      O    211       UK      M0    1    2019      UK
# 1546566   1       1      H    833       UK      M0    1    2019      UK
# 1546567   2       1      Q    263       UK      M0    1    2019      UK
# 1546568   1       1      O    532       UK      M0    1    2019      UK
#
#         REGION  ... COEFF_share_green_esco_median COEFF_share_green_esco_iqr  \
# 0           10  ...                      1.280184                   3.270349
# 1           10  ...                      2.751750                   6.879375
# 2           10  ...                      0.000000                   0.000000
# 3           10  ...                      2.521190                   1.334058
# 4           10  ...                      0.000000                   0.000000
# ...        ...  ...                           ...                        ...
# 1546564     M0  ...                      0.000000                   0.000000
# 1546565     M0  ...                     81.391364                 241.461045
# 1546566     M0  ...                     59.957419                  68.310462
# 1546567     M0  ...                      0.000000                   0.000000
# 1546568     M0  ...                      0.000000                   0.000000
#
#          COEFF_share_brown_esco_mean COEFF_share_brown_esco_std  \
# 0                           1.310335                   2.879087
# 1                           1.198619                   2.855575
# 2                           0.000000                   0.000000
# 3                           0.518645                   0.902814
# 4                           0.000000                   0.000000
# ...                              ...                        ...
# 1546564                     0.000000                   0.000000
# 1546565                    81.733828                 130.918147
# 1546566                    40.006625                  69.027988
# 1546567                     0.000000                   0.000000
# 1546568                     8.247900                  20.203146
#
#         COEFF_share_brown_esco_median COEFF_share_brown_esco_iqr  \
# 0                              0.0000                   1.561437
# 1                              0.0000                   1.421305
# 2                              0.0000                   0.000000
# 3                              0.0000                   0.756357
# 4                              0.0000                   0.000000
# ...                               ...                        ...
# 1546564                        0.0000                   0.000000
# 1546565                       29.8435                  99.478333
# 1546566                        0.0000                  64.235318
# 1546567                        0.0000                   0.000000
# 1546568                        0.0000                   0.000000
#
#         COEFF_share_neutral_esco_mean COEFF_share_neutral_esco_std  \
# 0                           78.380695                     6.216517
# 1                           74.043807                    12.870001
# 2                           47.232500                     0.000000
# 3                           49.757904                     1.892336
# 4                           75.636719                     0.782129
# ...                               ...                          ...
# 1546564                   1098.125092                     7.539097
# 1546565                   1533.571009                   328.865733
# 1546566                   1700.616274                   208.502745
# 1546567                   1719.291582                    16.704197
# 1546568                   2438.629100                    66.325972
#
#         COEFF_share_neutral_esco_median COEFF_share_neutral_esco_iqr
# 0                             79.705862                     5.083656
# 1                             78.207632                     9.660811
# 2                             47.232500                     0.000000
# 3                             49.919571                     1.359269
# 4                             75.862500                     0.000000
# ...                                 ...                          ...
# 1546564                     1100.140000                     0.000000
# 1546565                     1690.013933                   244.983955
# 1546566                     1722.679024                   147.931174
# 1546567                     1723.300000                     0.000000
# 1546568                     2474.370000                    37.115550
#
# [1546569 rows x 64 columns]

# %%
def perc_missing(df):
    return df.isna().sum() / df.shape[0]

perc_missing(df_all)
# Out:
# SEX                                0.000000
# WSTATOR                            0.000000
# NACE1D                             0.003823
# ISCO3D                             0.000000
# COUNTRYW                           0.000000
#                                      ...
# COEFF_share_brown_esco_iqr         0.010458
# COEFF_share_neutral_esco_mean      0.010458
# COEFF_share_neutral_esco_std       0.034960
# COEFF_share_neutral_esco_median    0.010458
# COEFF_share_neutral_esco_iqr       0.010458
# Length: 64, dtype: float64

# %%
countries = ["NL"]
perc_missing(df_all.loc[df_all["COUNTRY"].isin(countries)])
# Out:
# SEX                                0.000000
# WSTATOR                            0.000000
# NACE1D                             0.090380
# ISCO3D                             0.000000
# COUNTRYW                           0.000000
#                                      ...
# COEFF_share_brown_esco_iqr         0.015414
# COEFF_share_neutral_esco_mean      0.015414
# COEFF_share_neutral_esco_std       0.029811
# COEFF_share_neutral_esco_median    0.015414
# COEFF_share_neutral_esco_iqr       0.015414
# Length: 64, dtype: float64

# %%
ix_isco = df_all.loc[:, "ISCO3D"].sort_values().index.values
df_all.iloc[ix_isco]
# Out:
#         SEX WSTATOR NACE1D ISCO3D COUNTRYW REGIONW FTPT REFYEAR COUNTRY  \
# 1478168   1       1      O    000       SK      04    1    2019      SK
# 1171912   1       1      O    000       PL      61    1    2019      PL
# 1084604   1       1      O    000       MT     NaN    1    2019      MT
# 1084599   1       1      O    000       MT     NaN    1    2019      MT
# 1483567   1       1      O    000       SK      04    1    2019      SK
# ...      ..     ...    ...    ...      ...     ...  ...     ...     ...
# 890975    1       1      H    962       IT      G1    2    2019      IT
# 890985    1       1      T    962       IT      G1    1    2019      IT
# 1244683   1       1      O    962       PT      17    1    2019      PT
# 889573    1       1      N    962       IT      C4    1    2019      IT
# 766682    1       1      H    962       HU      32    1    2019      HU
#
#         REGION  ... COEFF_share_green_esco_median COEFF_share_green_esco_iqr  \
# 1478168     04  ...                           NaN                        NaN
# 1171912     61  ...                           NaN                        NaN
# 1084604    NaN  ...                           0.0                   0.000000
# 1084599    NaN  ...                           0.0                   0.000000
# 1483567     04  ...                           NaN                        NaN
# ...        ...  ...                           ...                        ...
# 890975      G1  ...                           0.0                   1.942648
# 890985      G1  ...                           0.0                   2.711999
# 1244683     17  ...                           0.0                   2.645960
# 889573      C4  ...                           0.0                   1.081390
# 766682      32  ...                           0.0                   1.136312
#
#          COEFF_share_brown_esco_mean COEFF_share_brown_esco_std  \
# 1478168                          NaN                        NaN
# 1171912                          NaN                        NaN
# 1084604                     0.030378                   0.139208
# 1084599                     0.069787                   0.319802
# 1483567                          NaN                        NaN
# ...                              ...                        ...
# 890975                      0.420032                   1.455034
# 890985                      0.586378                   2.031274
# 1244683                     0.572099                   1.981810
# 889573                      0.233814                   0.809956
# 766682                      0.245689                   0.851092
#
#         COEFF_share_brown_esco_median COEFF_share_brown_esco_iqr  \
# 1478168                           NaN                        NaN
# 1171912                           NaN                        NaN
# 1084604                           0.0                        0.0
# 1084599                           0.0                        0.0
# 1483567                           NaN                        NaN
# ...                               ...                        ...
# 890975                            0.0                        0.0
# 890985                            0.0                        0.0
# 1244683                           0.0                        0.0
# 889573                            0.0                        0.0
# 766682                            0.0                        0.0
#
#         COEFF_share_neutral_esco_mean COEFF_share_neutral_esco_std  \
# 1478168                           NaN                          NaN
# 1171912                           NaN                          NaN
# 1084604                     18.418138                     0.209708
# 1084599                     42.311939                     0.481763
# 1483567                           NaN                          NaN
# ...                               ...                          ...
# 890975                      63.362444                     4.166607
# 890985                      88.456002                     5.816717
# 1244683                     86.302017                     5.675075
# 889573                      35.271196                     2.319374
# 766682                      37.062557                     2.437171
#
#         COEFF_share_neutral_esco_median COEFF_share_neutral_esco_iqr
# 1478168                             NaN                          NaN
# 1171912                             NaN                          NaN
# 1084604                         18.5000                     0.000000
# 1084599                         42.5000                     0.000000
# 1483567                             NaN                          NaN
# ...                                 ...                          ...
# 890975                          65.5250                     2.759885
# 890985                          91.4750                     3.852887
# 1244683                         89.2475                     3.759066
# 889573                          36.4750                     1.536311
# 766682                          38.3275                     1.614338
#
# [1546569 rows x 64 columns]

# %%
cols = ["COEFF_share_green_esco_mean", "COEFF_share_brown_esco_mean",
        "COEFF_share_neutral_esco_mean"]

np.allclose(df_all.loc[:, cols].sum(axis=1), df_all.COEFF)
error = np.abs(df_all.loc[:, cols].sum(axis=1) - df_all.COEFF)

df_all.iloc[error.sort_values(ascending=False).index.values]
# Out:
#        SEX WSTATOR NACE1D ISCO3D COUNTRYW REGIONW FTPT REFYEAR COUNTRY REGION  \
# 529228   1       1      H    410       ES      61    1    2019      ES     61
# 596096   2       1    NaN    000       FR      E1    2    2019      FR     E1
# 539025   2       2      I    410       ES      30    1    2019      ES     30
# 535198   2       1      S    410       ES      51    1    2019      ES     51
# 548848   2       2      L    410       ES      30    1    2019      ES     30
# ...     ..     ...    ...    ...      ...     ...  ...     ...     ...    ...
# 565090   1       1      G    522       ES      21    1    2019      ES     21
# 565091   1       1      C    332       ES      51    1    2019      ES     21
# 565092   2       1      S    514       ES      21    1    2019      ES     21
# 565095   1       1      G    723       ES      24    1    2019      ES     24
# 565096   1       1      Q    221       ES      24    1    2019      ES     24
#
#         ... COEFF_share_green_esco_median COEFF_share_green_esco_iqr  \
# 529228  ...                           NaN                        NaN
# 596096  ...                           NaN                        NaN
# 539025  ...                           NaN                        NaN
# 535198  ...                           NaN                        NaN
# 548848  ...                           NaN                        NaN
# ...     ...                           ...                        ...
# 565090  ...                           NaN                        NaN
# 565091  ...                           NaN                        NaN
# 565092  ...                           NaN                        NaN
# 565095  ...                           NaN                        NaN
# 565096  ...                           NaN                        NaN
#
#         COEFF_share_brown_esco_mean COEFF_share_brown_esco_std  \
# 529228                          NaN                        NaN
# 596096                          NaN                        NaN
# 539025                          NaN                        NaN
# 535198                          NaN                        NaN
# 548848                          NaN                        NaN
# ...                             ...                        ...
# 565090                          NaN                        NaN
# 565091                          NaN                        NaN
# 565092                          NaN                        NaN
# 565095                          NaN                        NaN
# 565096                          NaN                        NaN
#
#        COEFF_share_brown_esco_median COEFF_share_brown_esco_iqr  \
# 529228                           NaN                        NaN
# 596096                           NaN                        NaN
# 539025                           NaN                        NaN
# 535198                           NaN                        NaN
# 548848                           NaN                        NaN
# ...                              ...                        ...
# 565090                           NaN                        NaN
# 565091                           NaN                        NaN
# 565092                           NaN                        NaN
# 565095                           NaN                        NaN
# 565096                           NaN                        NaN
#
#        COEFF_share_neutral_esco_mean COEFF_share_neutral_esco_std  \
# 529228                           NaN                          NaN
# 596096                           NaN                          NaN
# 539025                           NaN                          NaN
# 535198                           NaN                          NaN
# 548848                           NaN                          NaN
# ...                              ...                          ...
# 565090                           NaN                          NaN
# 565091                           NaN                          NaN
# 565092                           NaN                          NaN
# 565095                           NaN                          NaN
# 565096                           NaN                          NaN
#
#        COEFF_share_neutral_esco_median COEFF_share_neutral_esco_iqr
# 529228                             NaN                          NaN
# 596096                             NaN                          NaN
# 539025                             NaN                          NaN
# 535198                             NaN                          NaN
# 548848                             NaN                          NaN
# ...                                ...                          ...
# 565090                             NaN                          NaN
# 565091                             NaN                          NaN
# 565092                             NaN                          NaN
# 565095                             NaN                          NaN
# 565096                             NaN                          NaN
#
# [1546569 rows x 64 columns]

# %% [markdown]
# Group by LFS variables

# %%
age_by_gbn_shares = df_all.groupby("AGE")["COEFF_share_green_esco_mean",
                           "COEFF_share_brown_esco_mean",
                      "COEFF_share_neutral_esco_mean"].sum()

coeff_by_age = df_all.groupby("AGE")["COEFF"].sum()
# Out:
# C:\Users\fzaussinger\AppData\Local\Temp\ipykernel_10884\3363292881.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   age_by_gbn_shares = df_all.groupby("AGE")["COEFF_share_green_esco_mean",

# %%
age_by_gbn_shares_rel = age_by_gbn_shares.copy()
for col in age_by_gbn_shares_rel.columns:
    age_by_gbn_shares_rel[col] = age_by_gbn_shares_rel[col] / coeff_by_age

# %%
age_by_gbn_shares_rel
# Out:
#      COEFF_share_green_esco_mean  COEFF_share_brown_esco_mean  \
# AGE
# 17                      0.037356                     0.013639
# 22                      0.035036                     0.014717
# 27                      0.035378                     0.013889
# 32                      0.036670                     0.013594
# 37                      0.037622                     0.013591
# 42                      0.038605                     0.013792
# 47                      0.039654                     0.014099
# 52                      0.040693                     0.013859
# 57                      0.041822                     0.013975
# 62                      0.044325                     0.012843
# 67                      0.053531                     0.009329
# 72                      0.061286                     0.007869
#
#      COEFF_share_neutral_esco_mean
# AGE
# 17                        0.942190
# 22                        0.945911
# 27                        0.945189
# 32                        0.943112
# 37                        0.942746
# 42                        0.940969
# 47                        0.939980
# 52                        0.939299
# 57                        0.938003
# 62                        0.934646
# 67                        0.918282
# 72                        0.896492

# %%
age_by_gbn_shares_rel.plot.bar(stacked=True, figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='AGE'>
