# %% [markdown]
# # Validation of first, internal classification
# Felix Zaussinger | XX.YY.ZZZZ
#
# ## Core Analysis Goal(s)
# 1.
# 2.
# 3.
#
# ## Key Insight(s)
# 1.
# 2.
# 3.

# %%
import os
import sys
import logging
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from src import utils, plotting_utils
#import mapping_career_causeways

# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

# Settings
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

sns.set_context("talk")
sns.set(rc={'figure.figsize': (6, 3.)})
sns.set_style("ticks")

pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

logging.basicConfig(level=logging.INFO, stream=sys.stdout)

# load paths
useful_paths = utils.UsefulPaths()

# %%
def print_uniques_per_col(df):
    for col in df.columns:
        print(col, " : ", df[col].unique().shape[0])

# %% [markdown]
# 1) Import long lists

# %%
fpath_validated_gbn_classification = r"T:\Documents\Projects\04_jrc_green-skills-regional\02_research\2022-06-03_Occupation_Classification_Review_INTERNAL.xlsx"

dfs = pd.read_excel(
    fpath_validated_gbn_classification,
    sheet_name=None
)
# Out:
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# # IF TOBI STILL VALIDATES: RE-START ANALYSIS HERE
# Note 10.6.22

# %% [markdown]
# #### Final validated GBN classification file
#
# Versions
# - V2 : REVIEWED by JRC and D. Consoli
# - V3 : Additionally reviewed by Tobi
#
# - Lower bound --> manual classification (validated short list)
# - Upper bound --> threshold-based classification (long list)

# %%
fpath_manual_classification = r"T:\Documents\Projects\04_jrc_green-skills-regional\02_research\2022-06-03_Occupation_Classification_Review_MERGED_V6_short_tobi.xlsx"
dfs_manual_clsf = pd.read_excel(fpath_manual_classification, sheet_name=None, header=1)
# Out:
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# #### Green classification

# %% [markdown]
# The "lower bound green classification" results in 63 core green occupations. All raters need to rate them as TRUE. This is a very stringent selection !

# %%
dfs_manual_clsf["green_short_list"].is_green_final.sum()
# Out:
# 91

# %%
dfs_manual_clsf["green_short_list"]
# Out:
#                      preferredLabel  \
# 0             agricultural engineer
# 1            agricultural scientist
# 2           agricultural technician
# 3                        agronomist
# 4             air pollution analyst
# ..                              ...
# 175         water network operative
# 176          water plant technician
# 177           water quality analyst
# 178  waterway construction labourer
# 179              weather forecaster
#
#                                            description  \
# 0    Agricultural engineers intervene in a variety ...
# 1    Agricultural scientists research and study soi...
# 2    Agricultural technicians collect and conduct e...
# 3    Agronomists provide consulting services to com...
# 4    Air pollution analysts conduct field and lab t...
# ..                                                 ...
# 175  Water network operatives maintain pipes and pu...
# 176  Water plant technicians maintain and repair wa...
# ...

# %% [markdown]
# **Comparison within short list:**
# - looks well separated!

# %%
res = dfs_manual_clsf["green_short_list"].groupby("is_green_final").mean()
utils.extract_cols_by_kw(res, "share")
# Out:
#                 share_green_esco  share_green_esco_ess  share_green_gtp  \
# is_green_final
# False                   0.160105              0.146171         0.250794
# True                    0.368414              0.368135         0.438916
#
#                 share_green_jrc
# is_green_final
# False                  0.093086
# True                   0.175283

# %%
dfs_manual_clsf["green_short_list"]
# Out:
#                      preferredLabel  \
# 0             agricultural engineer
# 1            agricultural scientist
# 2           agricultural technician
# 3                        agronomist
# 4             air pollution analyst
# ..                              ...
# 175         water network operative
# 176          water plant technician
# 177           water quality analyst
# 178  waterway construction labourer
# 179              weather forecaster
#
#                                            description  \
# 0    Agricultural engineers intervene in a variety ...
# 1    Agricultural scientists research and study soi...
# 2    Agricultural technicians collect and conduct e...
# 3    Agronomists provide consulting services to com...
# 4    Air pollution analysts conduct field and lab t...
# ..                                                 ...
# 175  Water network operatives maintain pipes and pu...
# 176  Water plant technicians maintain and repair wa...
# ...

# %%
from statsmodels.stats import inter_rater as irr

ratings = dfs_manual_clsf["green_short_list"].loc[:, ("is_green_eth", "is_green_jrc", "is_green_consoli", "is_green_tobi")].to_numpy()
dats, cats = irr.aggregate_raters(ratings)
irr.fleiss_kappa(dats, method='fleiss')
# Out:
# 0.2903247609070323

# %% [markdown]
# **Comparison within long list (manual vs automatic classification)**
# - again, looks well separated!

# %%
set_diff_right = utils.get_set_diff(dfs_manual_clsf["green_short_list"], dfs["green_wide"], "preferredLabel")

green_long_vs_short_list = pd.merge(dfs["green_wide"], dfs_manual_clsf["green_short_list"][set_diff_right], how="left", on="preferredLabel")
green_long_vs_short_list.is_green_final = green_long_vs_short_list.is_green_final.fillna(False)

# %%
res = green_long_vs_short_list.groupby("is_green_final").mean()
utils.extract_cols_by_kw(res, "share")
# Out:
#                 share_green_esco  share_green_esco_ess  share_green_gtp  \
# is_green_final
# False                   0.076762              0.063748         0.095683
# True                    0.368414              0.368135         0.438916
#
#                 share_green_vona2018  share_green_jrc
# is_green_final
# False                       0.111495         0.070757
# True                        0.406538         0.175283

# %%
cols = ['is_green_final', 'share_green_esco', 'share_green_esco_ess', 'share_green_vona2018']

df_long = (
    green_long_vs_short_list[cols]
        .melt(id_vars="is_green_final")
)

ax = sns.boxplot(
    data=df_long,
    y="variable",
    x="value",
    hue="is_green_final",
    orient="h",
    width=0.5,
    fliersize=0.5,
    palette="Greys"
)

# %% [markdown]
# #### Brown classification

# %%
dfs_manual_clsf["brown_short_list"].is_brown_final.sum()
# Out:
# 63

# %%
dfs_manual_clsf["brown_short_list"]
# Out:
#                     preferredLabel  \
# 0       abrasive blasting operator
# 1    air separation plant operator
# 2       anodising machine operator
# 3           asphalt plant operator
# 4                          assayer
# ..                             ...
# 213                    well-digger
# 214  wire weaving machine operator
# 215      wood drying kiln operator
# 216                    wood sander
# 217                   wood treater
#
#                                            description  \
# 0    Abrasive blasting operators use the proper equ...
# 1    Air separation plant operators control and mai...
# 2    Anodising machine operators set up and tend an...
# 3    Asphalt plant operators extract raw materials ...
# 4    Assayers test and analyse precious metals such...
# ..                                                 ...
# 213  Well-diggers operate drilling machinery and eq...
# 214  Wire weaving machine operators set up and tend...
# ...

# %% [markdown]
# **Comparison within short list:**
# - looks well separated for ESCO scores
# - not well separated for ONET scores

# %%
res = dfs_manual_clsf["brown_short_list"].groupby("is_brown_final").mean()
utils.extract_cols_by_kw(res, "share")
# Out:
#                 share_brown_esco  share_brown_esco_ess  share_brown_vona2018
# is_brown_final
# False                   0.175003              0.174496              0.541188
# True                    0.138785              0.157967              0.482160

# %%
from statsmodels.stats import inter_rater as irr

ratings = dfs_manual_clsf["brown_short_list"].loc[:, ("is_brown_eth", "is_brown_jrc", "is_brown_consoli")].to_numpy()
#dats, cats = irr.aggregate_raters(ratings)
#irr.fleiss_kappa(dats, method='fleiss')

# %% [markdown]
# **Comparison within long list (manual vs automatic classification)**
# - again, looks well separated!

# %%
set_diff_right = utils.get_set_diff(dfs_manual_clsf["brown_short_list"], dfs["brown_widest"], "preferredLabel")

brown_long_vs_short_list = pd.merge(dfs["brown_widest"], dfs_manual_clsf["brown_short_list"][set_diff_right], how="left", on="preferredLabel")
brown_long_vs_short_list.is_brown_final = brown_long_vs_short_list.is_brown_final.fillna(False)

# %%
res = brown_long_vs_short_list.groupby("is_brown_final").mean()
utils.extract_cols_by_kw(res, "share")
# Out:
#                 share_brown_esco  share_brown_esco_ess  share_brown_vona2018
# is_brown_final
# False                   0.066932              0.062610              0.291375
# True                    0.138785              0.157967              0.482160

# %%
cols = ['is_brown_final', 'share_brown_esco', 'share_brown_esco_ess', 'share_brown_vona2018']

df_long = (
    brown_long_vs_short_list[cols]
        .melt(id_vars="is_brown_final")
)

ax = sns.boxplot(
    data=df_long,
    y="variable",
    x="value",
    hue="is_brown_final",
    orient="h",
    width=0.5,
    fliersize=0.5,
    palette="Greys"
)

# %%
import pingouin as pg
from scipy.stats import ttest_ind

ttest_ind(
    brown_long_vs_short_list.loc[brown_long_vs_short_list["is_brown_final"] == True]["share_brown_esco"],
    brown_long_vs_short_list.loc[brown_long_vs_short_list["is_brown_final"] == False]["share_brown_esco"]
)
# Out:
# Ttest_indResult(statistic=7.201856687821003, pvalue=1.2396057272837e-12)
# C:\Users\fzaussinger\Miniconda3\envs\re4gt\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# #### Prepare lower/upper bound files for export

# %% [markdown]
# 1) Brown file

# %%
cols2drop = ['gbn_classification_esco', 'gbn_classification_esco_ess', 'is_brown_eth', 'classification_felix', 'is_brown_felix2', 'is_brown_jrc', 'is_brown_consoli', 'is_brown_tobi', 'comment_tobi']
brown_long_vs_short_list_out = brown_long_vs_short_list.drop(columns=cols2drop)
brown_long_vs_short_list_out = brown_long_vs_short_list_out.rename(columns={"is_brown_final": "short_list_brown"})
brown_long_vs_short_list_out["long_list_brown"] = True
brown_long_vs_short_list_out
# Out:
#        id                                         conceptUri  \
# 0    1318  http://data.europa.eu/esco/occupation/5e748def...
# 1    1324  http://data.europa.eu/esco/occupation/f49d893a...
# 2    1316  http://data.europa.eu/esco/occupation/599c2ce9...
# 3    1005  http://data.europa.eu/esco/occupation/8d3fd879...
# 4     947  http://data.europa.eu/esco/occupation/ee37a4a5...
# ..    ...                                                ...
# 912  1305  http://data.europa.eu/esco/occupation/ac160654...
# 913  1302  http://data.europa.eu/esco/occupation/77a05858...
# 914  1304  http://data.europa.eu/esco/occupation/a77bc925...
# 915  1303  http://data.europa.eu/esco/occupation/7e08d38d...
# 916  1306  http://data.europa.eu/esco/occupation/ceb5277b...
#
#                         preferredLabel  \
# 0                        marine fitter
# 1        forestry machinery technician
# 2           forge equipment technician
# 3                      precast moulder
# ...

# %%
brown_long_vs_short_list_out.query("short_list_brown == True").groupby("isco_label_4").mean()
# Out:
#                                                              id  isco_level_4  \
# isco_label_4
# Agricultural and industrial machinery mechanics...  1321.000000        7233.0
# Cement, stone and other mineral products machin...  1002.000000        8114.0
# Chemical engineers                                   665.500000        2145.0
# Chemical processing plant controllers               1831.500000        3133.0
# Chemical products plant and machine operators        933.333333        8131.0
# Civil engineers                                      634.500000        2142.0
# Earthmoving and related plant operators             1139.000000        8342.0
# Electrical engineers                                 699.000000        2151.0
# Electrical mechanics and fitters                    1568.000000        7412.0
# Geologists and geophysicists                         733.000000        2114.0
# Glass and ceramics plant operators                  1096.333333        8181.0
# ...

# %%
brown_long_vs_short_list_out.query("long_list_brown == True").groupby("isco_label_4").mean()
# Out:
#                                                         id  isco_level_4  \
# isco_label_4
# Agricultural and industrial machinery mechanics...  1317.0        7233.0
# Agricultural technicians                            1846.5        3142.0
# Air conditioning and refrigeration mechanics        1514.0        7127.0
# Aircraft engine mechanics and repairers             1327.5        7232.0
# Aircraft pilots and related associate professio...  1594.0        3153.0
# ...                                                    ...           ...
# Welders and flamecutters                            1399.5        7212.0
# Well drillers and borers and related workers        1014.0        8113.0
# Wood processing plant operators                     1033.0        8172.0
# Wood treaters                                       1307.5        7521.0
# Woodworking-machine tool setters and operators      1303.5        7523.0
#
#                                                     isco_level_3  \
# ...

# %% [markdown]
# 2. Green file

# %%
cols2drop = ['gbn_classification_esco', 'gbn_classification_esco_ess', 'is_green_eth', 'is_green_jrc', 'is_green_consoli', 'is_green_tobi', 'comment_tobi']
green_long_vs_short_list_out = green_long_vs_short_list.drop(columns=cols2drop)
green_long_vs_short_list_out = green_long_vs_short_list_out.rename(columns={"is_green_final": "short_list_green"})
green_long_vs_short_list_out["long_list_green"] = True
green_long_vs_short_list_out
# Out:
#      Unnamed: 0                                         conceptUri  \
# 0            63  http://data.europa.eu/esco/occupation/bac64fa2...
# 1           130  http://data.europa.eu/esco/occupation/779d13be...
# 2           204  http://data.europa.eu/esco/occupation/114e1eff...
# 3           210  http://data.europa.eu/esco/occupation/ab762f91...
# 4           216  http://data.europa.eu/esco/occupation/fd4b90ed...
# ..          ...                                                ...
# 592        2982  http://data.europa.eu/esco/occupation/f272a521...
# 593        2983  http://data.europa.eu/esco/occupation/fb18dfef...
# 594        2985  http://data.europa.eu/esco/occupation/fb7e2f4f...
# 595        3006  http://data.europa.eu/esco/occupation/e1cf6897...
# 596        3007  http://data.europa.eu/esco/occupation/f756fdab...
#
#                    preferredLabel  \
# 0                 energy assessor
# 1    natural resources consultant
# 2     energy conservation officer
# ...

# %%
green_long_vs_short_list_out.query("short_list_green == True")
# Out:
#      Unnamed: 0                                         conceptUri  \
# 0            63  http://data.europa.eu/esco/occupation/bac64fa2...
# 1           130  http://data.europa.eu/esco/occupation/779d13be...
# 2           204  http://data.europa.eu/esco/occupation/114e1eff...
# 3           210  http://data.europa.eu/esco/occupation/ab762f91...
# 4           216  http://data.europa.eu/esco/occupation/fd4b90ed...
# 5           224  http://data.europa.eu/esco/occupation/b89ba3a8...
# 6           225  http://data.europa.eu/esco/occupation/c0489e22...
# 7           283  http://data.europa.eu/esco/occupation/8d586ee9...
# 8           284  http://data.europa.eu/esco/occupation/b7f47c25...
# 9           285  http://data.europa.eu/esco/occupation/0ecedad1...
# 10          288  http://data.europa.eu/esco/occupation/38d9c76b...
# 11          289  http://data.europa.eu/esco/occupation/4c715719...
# 12          296  http://data.europa.eu/esco/occupation/b09acdda...
# ...

# %%
green_long_vs_short_list_out.query("long_list_green == True").groupby("isco_label_4").mean()
# Out:
#                                                 Unnamed: 0  isco_level_4  \
# isco_label_4
# Agricultural and forestry production managers   563.000000        1311.0
# Agricultural technicians                        741.000000        3142.0
# Air conditioning and refrigeration mechanics    932.000000        7127.0
# Air traffic controllers                        2475.333333        3154.0
# Air traffic safety electronics technicians     1677.000000        3155.0
# ...                                                    ...           ...
# Veterinarians                                   857.333333        2250.0
# Veterinary technicians and assistants          1719.250000        3240.0
# Vocational education teachers                  1701.000000        2320.0
# Well drillers and borers and related workers   1252.000000        8113.0
# Window cleaners                                1071.000000        9123.0
#
#                                                isco_level_3  isco_level_2  \
# ...

# %%
green_long_vs_short_list_out.query("short_list_green == True")
# Out:
#      Unnamed: 0                                         conceptUri  \
# 0            63  http://data.europa.eu/esco/occupation/bac64fa2...
# 1           130  http://data.europa.eu/esco/occupation/779d13be...
# 2           204  http://data.europa.eu/esco/occupation/114e1eff...
# 3           210  http://data.europa.eu/esco/occupation/ab762f91...
# 4           216  http://data.europa.eu/esco/occupation/fd4b90ed...
# 5           224  http://data.europa.eu/esco/occupation/b89ba3a8...
# 6           225  http://data.europa.eu/esco/occupation/c0489e22...
# 7           283  http://data.europa.eu/esco/occupation/8d586ee9...
# 8           284  http://data.europa.eu/esco/occupation/b7f47c25...
# 9           285  http://data.europa.eu/esco/occupation/0ecedad1...
# 10          288  http://data.europa.eu/esco/occupation/38d9c76b...
# 11          289  http://data.europa.eu/esco/occupation/4c715719...
# 12          296  http://data.europa.eu/esco/occupation/b09acdda...
# ...

# %% [markdown]
# 3. Join to occ_metadata file & create long and short list classifications for subsetting

# %%
omd = pd.read_pickle(r"T:\Documents\Projects\04_jrc_green-skills-regional\03_data-analysis\re4gt\data\interim\esco\occ_metadata_en_esco_nan_values_filled.pkl")

omd_merged = pd.merge(omd, green_long_vs_short_list_out[["preferredLabel", "short_list_green", "long_list_green"]], how="left", on="preferredLabel")
omd_merged = pd.merge(omd_merged, brown_long_vs_short_list_out[["preferredLabel", "short_list_brown", "long_list_brown"]], how="left", on="preferredLabel")
omd_merged.query("short_list_green == True")
# Out:
#                                              conceptUri  \
# 204   http://data.europa.eu/esco/occupation/114e1eff...
# 216   http://data.europa.eu/esco/occupation/fd4b90ed...
# 321   http://data.europa.eu/esco/occupation/bf802371...
# 553   http://data.europa.eu/esco/occupation/0e99c929...
# 559   http://data.europa.eu/esco/occupation/42dbb769...
# 585   http://data.europa.eu/esco/occupation/f14194e2...
# 630   http://data.europa.eu/esco/occupation/3f3748a7...
# 632   http://data.europa.eu/esco/occupation/9740933e...
# 637   http://data.europa.eu/esco/occupation/e12f08fb...
# 639   http://data.europa.eu/esco/occupation/fcf9024e...
# 656   http://data.europa.eu/esco/occupation/32548f7e...
# 657   http://data.europa.eu/esco/occupation/7a523273...
# 658   http://data.europa.eu/esco/occupation/a7358961...
# 659   http://data.europa.eu/esco/occupation/ab4dd4f9...
# 660   http://data.europa.eu/esco/occupation/ac1fc6a9...
# 661   http://data.europa.eu/esco/occupation/c90e5009...
# ...

# %%
omd.preferredLabel.unique()
# Out:
# array(['technical director', 'video and motion picture director',
#        'performance lighting director', ..., 'pizzaiolo',
#        'kitchen assistant', 'kitchen porter'], dtype=object)

# %% [markdown]
# #### Prepare ESCO - KldB crosswalk
# final version

# %%
# read esco-kldb crosswalk
cw_kldb_merged_v2 = pd.read_pickle(os.path.join(useful_paths.data_processed, "crosswalks", "crosswalk_esco_kldb2010_final.pkl"))
cw_kldb_merged_v2
# Out:
#                                    Classification_1_URI  \
# 0                 http://data.europa.eu/esco/isco/C0110
# 1                 http://data.europa.eu/esco/isco/C0110
# 2                 http://data.europa.eu/esco/isco/C0110
# 3                 http://data.europa.eu/esco/isco/C0210
# 4                 http://data.europa.eu/esco/isco/C0210
# ...                                                 ...
# 8730  http://data.europa.eu/esco/occupation/e16e4cb0...
# 8731  http://data.europa.eu/esco/occupation/9e4269d5...
# 8732  http://data.europa.eu/esco/occupation/6e1b1bd7...
# 8733  http://data.europa.eu/esco/occupation/39c89133...
# 8734  http://data.europa.eu/esco/occupation/bb4ca5c1...
#
#                              Classification_1_PrefLabel  \
# 0                  Offiziere in regulären Streitkräften
# 1                  Offiziere in regulären Streitkräften
# 2                  Offiziere in regulären Streitkräften
# 3             Unteroffiziere in regulären Streitkräften
# ...

# %%
# read kldb names
kldb_names = pd.read_excel(r"T:\Documents\Projects\04_jrc_green-skills-regional\03_data-analysis\re4gt\rcode\B_Metadaten\Kldb2010-Englisch.xls", sheet_name="OccupationMetadata", usecols=["kldb2010_code", "kldb2010_name_de", "kldb2010_name_en"])
kldb_names
# Out:
#       kldb2010_code                                   kldb2010_name_de  \
# 0             11101  Berufe in der Landwirtschaft (ohne Spezialisie...
# 1             11102  Berufe in der Landwirtschaft (ohne Spezialisie...
# 2             11103  Berufe in der Landwirtschaft (ohne Spezialisie...
# 3             11104  Berufe in der Landwirtschaft (ohne Spezialisie...
# 4             11113  Berufe in der Landtechnik - komplexe Spezialis...
# ...             ...                                                ...
# 1281          94794                           Führungskräfte im Museum
# 1282           1104                                          Offiziere
# 1283           1203                        Unteroffiziere mit Portepee
# 1284           1302                       Unteroffiziere ohne Portepee
# 1285           1402  Angehörige der regulären Streitkräfte in sonst...
#
#                                        kldb2010_name_en
# 0     Occupations in farming (without specialisation...
# ...

# %%
# drop select columns for KLDB version (gilli, esco neutral, vona 2019)
omd_merged = omd_merged.drop(columns=["share_neutral_esco", "share_neutral_esco_ess", "share_green_vona2019", "share_green_gilli2020"])

# %% [markdown]
# #### GBN classification based on short lists (ESCO-level)
# - No need to do this for the long lists (there will be plenty of overlap, around n=263 occupations)

# %%
# find short list occupation classification
short_list_cols = omd_merged.columns[omd_merged.columns.str.contains("short_list")].tolist()
short_list_data = omd_merged[short_list_cols].fillna(False)

# make sure there is no overlap between short lists
assert short_list_data.query("short_list_green == True & short_list_brown == True").empty

# assign neutral occupations
short_list_data["short_list_neutral"] = False
short_list_data.loc[
    short_list_data.query("short_list_green == False & short_list_brown == False").index,
    "short_list_neutral"
] = True

# create classification column
short_list_classification = short_list_data.idxmax(axis=1).str.split(pat="_", expand=True).iloc[:, 2]
omd_merged["gbn_classification_short_list"] = short_list_classification

# %%
# save to data/processed
esco_level_gbn_classification = omd_merged[["conceptUri", "preferredLabel", "description", "gbn_classification_esco", "gbn_classification_esco_ess", "gbn_classification_short_list"]]
esco_level_gbn_classification.to_csv(os.path.join(useful_paths.data_processed, "esco", "esco_level_gbn_classification_short_lists_tobi.csv"))

# %% [markdown]
# #### Average at KldB level and write versions to excel

# %%
# create excel sheet
cw_esco_kldb = cw_kldb_merged_v2
fname_out = 'occ_metadata_en_kldb2010_final_v5_short_list_tobi_updated.xlsx'
with pd.ExcelWriter(os.path.join(useful_paths.data_processed, "esco", fname_out)) as writer:

    # 1) full version
    # --------------------------------------------
    cw_kldb_merged_with_omd = pd.merge(
    cw_esco_kldb,
    omd_merged,
    left_on="Classification_1_URI",
    right_on="conceptUri",
    how="left"
).drop(columns=["Classification_2_ID"])

    kldb_level_shares = cw_kldb_merged_with_omd.groupby("kldb2010_code").mean().reset_index()
    kldb_level_shares = pd.merge(kldb_names, kldb_level_shares, on="kldb2010_code", how="left")

    # write to excel
    kldb_level_shares.to_excel(writer, sheet_name='full_list')

    # 2) Upper/lower bound versions
    # --------------------------------------------
    subset_versions = ["short_list_green", "short_list_brown", "long_list_green", "long_list_brown"]

    for subset_version in subset_versions:
        cw_kldb_merged_with_omd_subset = pd.merge(
            cw_esco_kldb,
            omd_merged.query("{} == True".format(subset_version)),
            left_on="Classification_1_URI",
            right_on="conceptUri",
            how="left"
        ).drop(columns=["Classification_2_ID"])

        cw_kldb_merged_with_omd_subset = cw_kldb_merged_with_omd_subset.fillna(0)
        kldb_level_shares = cw_kldb_merged_with_omd_subset.groupby("kldb2010_code").mean().reset_index()
        kldb_level_shares = pd.merge(kldb_names, kldb_level_shares, on="kldb2010_code", how="left")

        # write to excel
        kldb_level_shares.to_excel(writer, sheet_name=subset_version)

writer.save()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <module>
#      39         # write to excel
#      40         kldb_level_shares.to_excel(writer, sheet_name=subset_version)
# ---> 42 writer.save()
#
# File ~\Miniconda3\envs\re4gt\lib\site-packages\pandas\io\excel\_openpyxl.py:81, in OpenpyxlWriter.save(self)
#      77 def save(self):
#      78     """
#      79     Save workbook to disk.
#      80     """
# ---> 81     self.book.save(self.handles.handle)
#      82     if "r+" in self.mode and not isinstance(self.handles.handle, mmap.mmap):
#      83         # truncate file to the written content
#      84         self.handles.handle.truncate()
#
# File ~\Miniconda3\envs\re4gt\lib\site-packages\openpyxl\workbook\workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# ...

# %% [markdown]
# Number of G/B/N ESCO occupations per KldB code

# %%
cat_per_kldb_code = cw_kldb_merged_with_omd.groupby(["kldb2010_code", "gbn_classification_short_list"])["gbn_classification_short_list"].count().rename("n_esco").reset_index()
cat_per_kldb_code["multiple_cats"] = cat_per_kldb_code.duplicated(subset=["kldb2010_code"], keep=False)

kldb_gbn_classification = pd.merge(kldb_names, cat_per_kldb_code, on="kldb2010_code", how="left")

# save
fpath_out = os.path.join(useful_paths.data_processed, "esco", "occ_metadata_en_kldb2010_final_v5_short_list_tobi_gbn_clsf_updated.xlsx")
if not os.path.exists(fpath_out):
    print("saving")
    kldb_gbn_classification.to_excel(fpath_out)
# Out:
# saving

# %%
cnt = 0
data_store = []
cols_all = {"green", "brown", "neutral"}

for grp, grp_df in kldb_gbn_classification.groupby("kldb2010_code"):

    # pivot long to wide, simplify multi-indices
    grp_df_piv = grp_df.pivot(index=["kldb2010_code", "kldb2010_name_de", "kldb2010_name_en", "multiple_cats"], columns=["gbn_classification_short_list"], values=["n_esco"])
    grp_df_piv.columns = grp_df_piv.columns.get_level_values(1)
    grp_df_piv = grp_df_piv.reset_index()
    #grp_df_piv.index = grp_df_piv.index.get_level_values(0)

    # create missing column
    cols_exist = set(grp_df_piv.columns.tolist())
    col_missing = list(cols_all - cols_exist)
    grp_df_piv[col_missing] = 0

    # calc shares
    grp_df_piv["N"] = grp_df_piv[list(cols_all)].sum(axis=1)

    for col in list(cols_all):
        grp_df_piv["share_{}".format(col)] = grp_df_piv[col] / grp_df_piv["N"]

    # append
    data_store.append(grp_df_piv)

# concat to new df
df_out = pd.concat(data_store)

# assign category where data is available
df_out["category"] = df_out[list(cols_all)].idxmax(axis=1)
df_out = df_out.reset_index(drop=True)
df_out.loc[df_out['multiple_cats'].isna(), "category"] = None

# drop empty column
df_out = df_out.dropna(axis=1, how="all")

# %%
# save
fpath_out = os.path.join(useful_paths.data_processed, "esco", "occ_metadata_en_kldb2010_final_v5_short_list_tobi_gbn_clsf_updated_reformatted.xlsx")
if not os.path.exists(fpath_out):
    print("saving")
    df_out.to_excel(fpath_out)
# Out:
# saving
