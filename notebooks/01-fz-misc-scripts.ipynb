# %%
import os
import copy
import numpy as np
import pandas as pd
import geopandas as gpd

from pathlib import Path

from src import utils

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context("paper", font_scale=1.25)

from src.data.lfs import EulfsDs

# %load_ext autoreload
# %autoreload 2

# %%
gdf1 = gpd.read_file(r"T:\Documents\Projects\04_jrc_green-skills-regional\03_data"
                    r"-analysis\re4gt\data\external\geodata\NUTS_RG_03M_2021_4326.shp")

# %%
nuts_lvl = 2
gdf1.loc[gdf1["LEVL_CODE"] == nuts_lvl]
# Out:
#      NUTS_ID  LEVL_CODE CNTR_CODE                            NAME_LATN  \
# 86      AL01          2        AL                                 Veri
# 87      AL02          2        AL                               Qender
# 89      DE24          2        DE                          Oberfranken
# 103     IE05          2        IE                             Southern
# 109     HU11          2        HU                             Budapest
# ...      ...        ...       ...                                  ...
# 1543    NO02          2        NO                            Innlandet
# 1598    NO06          2        NO                            Trøndelag
# 1599    NO07          2        NO                           Nord-Norge
# 1728    NO08          2        NO                        Oslo og Viken
# 1938    LT02          2        LT  Vidurio ir vakarų Lietuvos regionas
#
#                                 NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# ...

# %%
gdf2 = gpd.read_file(r"T:\Documents\Projects\04_jrc_green-skills-regional\03_data"
                     r"-analysis\re4gt\data\external\geodata\NUTS_RG_03M_2021_4326_LEVL_2")

# %%
gdf2
# Out:
#     NUTS_ID  LEVL_CODE CNTR_CODE                            NAME_LATN  \
# 0      AL01          2        AL                                 Veri
# 1      AL02          2        AL                               Qender
# 2      DE24          2        DE                          Oberfranken
# 3      IE05          2        IE                             Southern
# 4      HU11          2        HU                             Budapest
# ..      ...        ...       ...                                  ...
# 329    NO02          2        NO                            Innlandet
# 330    NO06          2        NO                            Trøndelag
# 331    NO07          2        NO                           Nord-Norge
# 332    NO08          2        NO                        Oslo og Viken
# 333    LT02          2        LT  Vidurio ir vakarų Lietuvos regionas
#
#                                NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# ...
